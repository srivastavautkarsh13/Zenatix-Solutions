# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("AC_Data.csv")

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
#displaying large  umber of rows to understand the data
df.head()
# Out:
#        AC 1      AC 2  AC 3  AC 4      AC 5      AC 6      AC 7      AC 8  \
# 0  7.518632  8.788315   0.0   0.0  2.617045  4.079041  2.782276  4.624447
# 1  0.000000  0.000000   0.0   0.0  0.000000  0.000000  0.000000  0.000000
# 2  7.426114  8.940615   0.0   0.0  2.581625  3.781231  2.529366  5.057423
# 3  0.000000  0.000000   0.0   0.0  0.000000  0.000000  0.000000  0.000000
# 4  7.052986  9.161103   0.0   0.0  2.592095  3.800127  2.332304  6.322521
#
#        AC 9     AC 10     AC 11     AC 12     AC 13     AC 14     AC 15  \
# 0  5.222060  2.151238  1.585072  0.560373  3.142941  2.749470  5.417774
# 1  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  5.349465  2.414715  2.168184  1.818730  3.085110  2.720484  3.302422
# 3  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4  3.995392  2.237114  3.345624  2.310409  3.132799  2.676861  3.539026
#
#       AC 16     AC 17     AC 18            datetime  month  day  hour  minute
# ...

# %%
#displaying large  umber of rows to understand the data
df.tail()
# Out:
#            AC 1      AC 2      AC 3      AC 4      AC 5      AC 6      AC 7  \
# 87835  0.000000  6.122385  2.192198  2.083315  1.046250  0.000000  3.668421
# 87836  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 87837  1.209176  6.152532  2.211421  0.000000  1.448103  0.000000  3.151248
# 87838  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 87839  1.430442  6.078281  1.891162  0.000000  1.577491  4.364239  3.126339
#
#            AC 8      AC 9     AC 10     AC 11     AC 12     AC 13     AC 14  \
# 87835  3.006311  3.614301  1.860847  5.019769  3.154221  3.648026  2.439526
# 87836  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 87837  2.871690  3.417942  2.185493  5.174168  2.772349  3.786657  2.060023
# 87838  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 87839  3.287224  3.986978  2.013912  4.821829  3.363855  3.380110  1.949240
#
# ...

# %%
df.shape
# Out:
# (87840, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87840 entries, 0 to 87839
# Data columns (total 19 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       87840 non-null  object
#  1   AC 1    43708 non-null  float64
#  2   AC 2    43711 non-null  float64
#  3   AC 3    43713 non-null  float64
#  4   AC 4    43704 non-null  float64
#  5   AC 5    43716 non-null  float64
#  6   AC 6    43717 non-null  float64
#  7   AC 7    43679 non-null  float64
#  8   AC 8    43704 non-null  float64
#  9   AC 9    43654 non-null  float64
#  10  AC 10   43690 non-null  float64
#  11  AC 11   43670 non-null  float64
#  12  AC 12   43713 non-null  float64
#  13  AC 13   43719 non-null  float64
#  14  AC 14   43696 non-null  float64
#  15  AC 15   43715 non-null  float64
#  16  AC 16   43710 non-null  float64
#  17  AC 17   43714 non-null  float64
#  18  AC 18   43723 non-null  float64
# dtypes: float64(18), object(1)
# memory usage: 12.7+ MB

# %%
(df.isnull().sum()/len(df))*100
# Out:
# 0         0.000000
# AC 1     50.241348
# AC 2     50.237933
# AC 3     50.235656
# AC 4     50.245902
# AC 5     50.232240
# AC 6     50.231102
# AC 7     50.274362
# AC 8     50.245902
# AC 9     50.302823
# AC 10    50.261840
# AC 11    50.284608
# AC 12    50.235656
# AC 13    50.228825
# AC 14    50.255009
# AC 15    50.233379
# AC 16    50.239071
# AC 17    50.234517
# AC 18    50.224271
# dtype: float64

# %% [markdown]
# Its clear from the data that Power Consumption is available for the months of August and September.
# Also, data is recorded after every two minutes gap, thats why half of the values are NULL.

# %%
df['datetime'] = pd.to_datetime(df['0'])

# %%
df.columns
# Out:
# Index(['0', 'AC 1', 'AC 2', 'AC 3', 'AC 4', 'AC 5', 'AC 6', 'AC 7', 'AC 8',
#        'AC 9', 'AC 10', 'AC 11', 'AC 12', 'AC 13', 'AC 14', 'AC 15', 'AC 16',
#        'AC 17', 'AC 18', 'datetime'],
#       dtype='object')

# %%
df['month'] = df['datetime'].apply(lambda x : x.month)
df['day'] = df['datetime'].apply(lambda x : x.day)
df['hour'] = df['datetime'].apply(lambda x : x.hour)
df['minute'] = df['datetime'].apply(lambda x : x.minute)

# %%
df.head()
# Out:
#                      0      AC 1      AC 2  AC 3  AC 4      AC 5      AC 6  \
# 0  2019-08-01 00:00:00  7.518632  8.788315   0.0   0.0  2.617045  4.079041
# 1  2019-08-01 00:01:00       NaN       NaN   NaN   NaN       NaN       NaN
# 2  2019-08-01 00:02:00  7.426114  8.940615   0.0   0.0  2.581625  3.781231
# 3  2019-08-01 00:03:00       NaN       NaN   NaN   NaN       NaN       NaN
# 4  2019-08-01 00:04:00  7.052986  9.161103   0.0   0.0  2.592095  3.800127
#
#        AC 7      AC 8      AC 9     AC 10     AC 11     AC 12     AC 13  \
# 0  2.782276  4.624447  5.222060  2.151238  1.585072  0.560373  3.142941
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2  2.529366  5.057423  5.349465  2.414715  2.168184  1.818730  3.085110
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4  2.332304  6.322521  3.995392  2.237114  3.345624  2.310409  3.132799
#
#       AC 14     AC 15     AC 16     AC 17     AC 18            datetime  \
# ...

# %%
df.drop(['0'], axis=1, inplace=True)

# %%
df.head()
# Out:
#        AC 1      AC 2  AC 3  AC 4      AC 5      AC 6      AC 7      AC 8  \
# 0  7.518632  8.788315   0.0   0.0  2.617045  4.079041  2.782276  4.624447
# 1       NaN       NaN   NaN   NaN       NaN       NaN       NaN       NaN
# 2  7.426114  8.940615   0.0   0.0  2.581625  3.781231  2.529366  5.057423
# 3       NaN       NaN   NaN   NaN       NaN       NaN       NaN       NaN
# 4  7.052986  9.161103   0.0   0.0  2.592095  3.800127  2.332304  6.322521
#
#        AC 9     AC 10     AC 11     AC 12     AC 13     AC 14     AC 15  \
# 0  5.222060  2.151238  1.585072  0.560373  3.142941  2.749470  5.417774
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2  5.349465  2.414715  2.168184  1.818730  3.085110  2.720484  3.302422
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4  3.995392  2.237114  3.345624  2.310409  3.132799  2.676861  3.539026
#
#       AC 16     AC 17     AC 18            datetime  month  day  hour  minute
# ...

# %%
df.columns
# Out:
# Index(['AC 1', 'AC 2', 'AC 3', 'AC 4', 'AC 5', 'AC 6', 'AC 7', 'AC 8', 'AC 9',
#        'AC 10', 'AC 11', 'AC 12', 'AC 13', 'AC 14', 'AC 15', 'AC 16', 'AC 17',
#        'AC 18', 'datetime', 'month', 'day', 'hour', 'minute'],
#       dtype='object')

# %% [markdown]
# Now, We have recordings for every minute and half of the data is NULL.

# %% [markdown]
# Instead of dropping all the NULL values, lets convert our data from minute consumption into hourly basis consumption for everyday.

# %%
#keeping it as a backup of original data
new_df = df.copy()

# %%
df.fillna(0, inplace=True)

# %%
(df.isnull().sum()/len(df))*100
# Out:
# AC 1        0.0
# AC 2        0.0
# AC 3        0.0
# AC 4        0.0
# AC 5        0.0
# AC 6        0.0
# AC 7        0.0
# AC 8        0.0
# AC 9        0.0
# AC 10       0.0
# AC 11       0.0
# AC 12       0.0
# AC 13       0.0
# AC 14       0.0
# AC 15       0.0
# AC 16       0.0
# AC 17       0.0
# AC 18       0.0
# datetime    0.0
# month       0.0
# day         0.0
# hour        0.0
# minute      0.0
# dtype: float64

# %%
df.head()
# Out:
#        AC 1      AC 2  AC 3  AC 4      AC 5      AC 6      AC 7      AC 8  \
# 0  7.518632  8.788315   0.0   0.0  2.617045  4.079041  2.782276  4.624447
# 1  0.000000  0.000000   0.0   0.0  0.000000  0.000000  0.000000  0.000000
# 2  7.426114  8.940615   0.0   0.0  2.581625  3.781231  2.529366  5.057423
# 3  0.000000  0.000000   0.0   0.0  0.000000  0.000000  0.000000  0.000000
# 4  7.052986  9.161103   0.0   0.0  2.592095  3.800127  2.332304  6.322521
#
#        AC 9     AC 10     AC 11     AC 12     AC 13     AC 14     AC 15  \
# 0  5.222060  2.151238  1.585072  0.560373  3.142941  2.749470  5.417774
# 1  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  5.349465  2.414715  2.168184  1.818730  3.085110  2.720484  3.302422
# 3  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4  3.995392  2.237114  3.345624  2.310409  3.132799  2.676861  3.539026
#
#       AC 16     AC 17     AC 18            datetime  month  day  hour  minute
# ...

# %%
'''hour_df = df.groupby(['month','day','hour'],as_index=False)['AC 1', 'AC 2', 'AC 3', 'AC 4', 'AC 5', 'AC 6', 'AC 7', 'AC 8', 'AC 9',
       'AC 10', 'AC 11', 'AC 12', 'AC 13', 'AC 14', 'AC 15', 'AC 16', 'AC 17',
       'AC 18'].sum()'''

hour_df = df.groupby(['month','hour'],as_index=False)['AC 1', 'AC 2', 'AC 3', 'AC 4', 'AC 5', 'AC 6', 'AC 7', 'AC 8', 'AC 9',
       'AC 10', 'AC 11', 'AC 12', 'AC 13', 'AC 14', 'AC 15', 'AC 16', 'AC 17',
       'AC 18'].sum()
# Out:
# <ipython-input-37-a97686922417>:5: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   hour_df = df.groupby(['month','hour'],as_index=False)['AC 1', 'AC 2', 'AC 3', 'AC 4', 'AC 5', 'AC 6', 'AC 7', 'AC 8', 'AC 9',

# %%
hour_df.head()
# Out:
#    month  hour         AC 1         AC 2         AC 3         AC 4  \
# 0      8     0  3120.304442  4424.217386  2452.611949  2475.950995
# 1      8     1  3190.515598  4256.212569  2516.742198  2482.591014
# 2      8     2  3173.984538  4303.350055  2551.489828  2667.706978
# 3      8     3  3040.320189  4242.885373  2540.399488  2594.244080
# 4      8     4  2915.538058  4118.351680  2495.437653  2571.553638
#
#           AC 5         AC 6         AC 7         AC 8         AC 9  \
# 0  1368.535430  2608.841387  3432.255884  2922.665952  3466.585732
# 1  1329.353386  2675.986514  3311.846589  2866.886756  3379.946839
# 2  1396.175285  2803.787954  3309.439501  2855.627261  3360.479040
# 3  1348.165036  2644.397321  3307.142308  2844.708395  3284.705609
# 4  1355.229713  2526.517727  3296.930470  2740.151189  3367.088089
#
#          AC 10        AC 11        AC 12        AC 13        AC 14  \
# 0  1926.521868  2940.759069  3191.637622  4523.666270  3457.015174
# ...

# %%
ac_columns = ['AC 1', 'AC 2', 'AC 3', 'AC 4', 'AC 5', 'AC 6', 'AC 7', 'AC 8', 'AC 9',
       'AC 10', 'AC 11', 'AC 12', 'AC 13', 'AC 14', 'AC 15', 'AC 16', 'AC 17',
       'AC 18']
hour_df[ac_columns].describe()
# Out:
#               AC 1         AC 2         AC 3         AC 4         AC 5  \
# count    48.000000    48.000000    48.000000    48.000000    48.000000
# mean   2166.612979  3523.190582  2339.019938  2180.791776  1294.812659
# std     503.196917   405.336935   234.121375   275.677347   119.990826
# min    1480.171283  2890.362158  1903.945288  1656.272819  1054.134105
# 25%    1737.856297  3236.741560  2157.794904  1964.322976  1220.179661
# 50%    2053.613435  3468.118239  2377.340892  2161.249391  1282.129831
# 75%    2636.596560  3813.391169  2503.633342  2420.301526  1352.182560
# max    3190.515598  4424.217386  2828.961583  2667.706978  1545.589268
#
#               AC 6         AC 7         AC 8         AC 9        AC 10  \
# count    48.000000    48.000000    48.000000    48.000000    48.000000
# mean   2293.446498  2712.541861  2320.601171  2896.063002  1400.213083
# std     451.455328   396.972796   509.580416   392.278187   267.682889
# ...

# %%
#sns.boxplot(data=hour_df)

# %%
plt.figure(figsize=(12,5))
sns.barplot(x=ac_columns,y=hour_df[ac_columns].describe().loc['mean'],orient='v')
plt.ylabel('watts')
plt.title('Average Power consumption of ACs for August and September months')
# Out:
# Text(0.5, 1.0, 'Average Power consumption of ACs for August and September months')

# %%
plt.figure(figsize=(20,10))
count = 1
for ac in ac_columns:
    plt.subplot(6,3,count)
    count += 1
    sns.lineplot(x='hour',y=ac,data=hour_df,hue='month')

# %%
hour_df.plot(grid=True)
# Out:
# <AxesSubplot:>

# %%
hour_df.groupby(['month'])['AC 1'].max().loc()
